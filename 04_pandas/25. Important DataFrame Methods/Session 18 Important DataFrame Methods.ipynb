# %% [markdown]
# # Session 18: Important DataFrame Methods

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### `value_counts()`
# Returns a Series containing the count of unique items.

# %%
# implementing on a Series
a = pd.Series([1, 1, 2, 2, 3])
a.value_counts()
# Out:
# 1    2
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
# implementing on a DataFrame
marks = pd.DataFrame([
    [100, 80, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 70, 14],
    [80, 70, 14]
], columns=['iq', 'marks', 'package'])
print(marks)
marks.value_counts()
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14
# iq   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %% [markdown]
# In a DataFrame, it counts the occurence of each row in the entire dataframe, i.e. duplicate rows.

# %% [markdown]
# ### Some tasks on ipl Dataset using `value_counts()`

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %% [markdown]
# #### Task: Find which player has won the most 'Player of the Match', in Finals and Qualifiers.

# %%
ipl['MatchNumber'].value_counts() == 1
# Out:
# MatchNumber
# Final                 False
# 41                    False
# 40                    False
# 43                    False
# 46                    False
#                       ...
# Qualifier             False
# Elimination Final     False
# 72                    False
# 71                    False
# 3rd Place Play-Off     True
# Name: count, Length: 80, dtype: bool

# %%
~ ipl['MatchNumber'].str.isdigit() # returns boolean series of values which are not digits, i.e. special matches
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
# applying the above defined mask in ipl df
ipl[~ ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %% [markdown]
# This lists all of the players who have won 'Player of the Match' in Final or Qualifying matches.

# %% [markdown]
# #### Toss decision plot (Pie Chart)

# %%
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# This concludes that majority of the times, the team captains choose **fielding** than **batting**.

# %% [markdown]
# #### Task: How many matches has each time played?

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# ### `sort_values()`
# Sorts the values on the basis of some values of a column or Series.

# %%
x = pd.Series([12, 14, 1, 56, 89])
x
# Out:
# 0    12
# 1    14
# 2     1
# 3    56
# 4    89
# dtype: int64

# %%
x.sort_values(ascending=False)
# Out:
# 4    89
# 3    56
# 1    14
# 0    12
# 2     1
# dtype: int64

# %%
movies = pd.read_csv('movies.csv')
movies.head(4)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %% [markdown]
# Sort the dataframe rows on the basis of a column.

# %%
movies.sort_values(['title_x'])
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# Now, trying to emply `sort_values()` on a DataFrame containing **NaN** values.

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values(by='name', na_position='first')
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %% [markdown]
# By default, `sort_values()` places the rows with **NaN** values at the last. Though this can be changed by using the `na_position` param, as shown in the above code cell.

# %% [markdown]
# #### Task: Sort the movies DataFrame as per the year of release firsthand. Secondly, sort the pre-sorted DataFrame alphabetically while preserving the year basis sort.

# %%
movies.sort_values(['year_of_release', 'title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### `rank()`
# Ranks the rows on the basis of the numeric values of a column. Row with the least value occurs at the first place by default. Only applicable on a **Series**.

# %%
batsman = pd.read_csv('batsman_runs_ipl.csv')
batsman.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
batsman['batsman_run'].rank(ascending=False)
# Out:
# 0      166.5
# 1      226.0
# 2      535.0
# 3      329.0
# 4      402.5
#        ...
# 600    594.0
# 601    343.0
# 602    547.5
# 603     27.0
# 604    256.0
# Name: batsman_run, Length: 605, dtype: float64

# %%
# creating a new column for rank in the df
batsman['batting_rank'] = batsman['batsman_run'].rank(ascending=False)
batsman.head()
# Out:
#            batter  batsman_run  batting_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 4     A Choudhary           25         402.5

# %% [markdown]
# Now we can simply sort the whole DataFrame with respect to the 'batting_rank' column.

# %%
batsman.sort_values(by='batting_rank')
# Out:
#            batter  batsman_run  batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 600    Yash Dayal            0         594.0
# 595    YA Abdulla            0         594.0
# 57         AS Roy            0         594.0
# 63   Abdur Razzak            0         594.0
# 65     Akash Deep            0         594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# ### `sort_index()`
# Sorts the rows of the DataFrame as per the **index** of the DataFrame.

# %%
marks = {
    'maths': 67,
    'english': 57,
    'science': 89,
    'hindi': 100
}
marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# sorting the rows alphabetically on index
marks_series.sort_index()
# Out:
# english     57
# hindi      100
# maths       67
# science     89
# dtype: int64

# %%
# another example of sort_index()
movies.sort_index(ascending=False).head(5)
# Out:
#                     title_x     imdb_id  \
# 1628               Humsafar   tt2403201
# 1627                  Daaka  tt10833860
# 1626        Sabse Bada Sukh   tt0069204
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1624  Tera Mera Saath Rahen   tt0301250
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
#
#                                               wiki_link  \
# 1628             https://en.wikipedia.org/wiki/Humsafar
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
#
# ...

# %% [markdown]
# ### `set_index()`
# Set the DataFrame index using the existing columns. Only applicable on DataFrames.

# %%
batsman.set_index('batter', inplace=True)

# %%
batsman.sample(2)
# Out:
#           batsman_run  batting_rank
# batter
# C Madan            15         453.5
# GC Smith          739          99.0

# %% [markdown]
# ### `reset_index()`
# Resets the index of the DataFrame and uses the default one instead. Applicable on both Series and DataFrames.
# > Warning: To replace the index without using the existing one, do not directly set index, but first reset index and then set the new column. Else the existing index column will be deleted.

# %%
batsman.reset_index()
batsman.sample()
# Out:
#          batsman_run  batting_rank
# batter
# A Nehra           41         352.0

# %%
marks_series = marks_series.reset_index()
type(marks_series)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Upon observing the above code cell, we realise that we can make a DataFrame out of a Series merely by using `reset_index()`

# %% [markdown]
# ### `rename()`
# Renames the names of the columns in the DataFrame. Applicable only on a DataFrame.

# %%
movies.set_index('title_x', inplace=True)

# %%
movies.rename(columns={'imdb_id': 'imdb', 'poster_path': 'URL'}, inplace=True)
movies.sample()
# Out:
#                  imdb                                                URL  \
# title_x
# Sonchiriya  tt8108200  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link     title_y  \
# title_x
# Sonchiriya  https://en.wikipedia.org/wiki/Sonchiriya  Sonchiriya
#
#            original_title  is_adult  year_of_release runtime  \
# title_x
# Sonchiriya     Sonchiriya         0             2019     143
#
#                         genres  imdb_rating  imdb_votes  \
# title_x
# Sonchiriya  Action|Crime|Drama          7.5        2322
#
#                                                         story  \
# title_x
# Sonchiriya  This is the story of a group of rebels in Cham...
#
#                                                       summary tagline  \
# title_x
# Sonchiriya  Set in the Chambal valley  the film follows th...     NaN
#
#                                                        actors  \
# title_x
# ...

# %% [markdown]
# Similarly, we can also rename the name of the index in DataFrame.

# %%
movies.rename(index={'Uri: The Surgical Strike': 'Uri', 'Battalion 609': 'Battalion'})
# Out:
#                                             imdb  \
# title_x
# Uri                                    tt8291224
# Battalion                              tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                     URL  \
# title_x
# Uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion                                                                           NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### `unique()`
# Lists all the unique values in the Series. Works only on Series.

# %%
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %% [markdown]
# Now suppose we need to have a count the number of unique values, we may do the following:
# > We must note that `nunique()` method will not consider missing, i.e. `NaN` values.

# %%
# either of the ways will work
print(len(ipl['Season'].unique()))
print(ipl['Season'].unique().shape[0])
print(ipl['Season'].nunique())
# Out:
# 15
# 15
# 15

# %% [markdown]
# ## Some methods on missing values

# %% [markdown]
# ### `isnull()`
# Returns a **Boolean Series**, placing *True* where there is a **NaN** value and *False* where there is not.

# %%
students['name'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
students[students['name'].isnull()]
# Out:
#   name college branch  cgpa  package
# 3  NaN     NaN    NaN   NaN      NaN
# 5  NaN    vlsi     ce   9.0      7.0
# 7  NaN     NaN    cse  10.0      9.0
# 9  NaN     git    NaN   NaN      NaN

# %% [markdown]
# ### `notnull()`
# Works just the opposite of `isnull()`, returns a **Boolean Series**, stating *False* where the value is Null and *True* where it is not.

# %%
students['name'].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# Name: name, dtype: bool

# %%
students[students['name'].notnull()]
# Out:
#          name college branch  cgpa  package
# 0      nitish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 8      aditya     NaN    bio  7.40      NaN

# %% [markdown]
# ### `hasnans()`
# Checks if the entire Series has **NaN** values or not. Returns *True* if there are, and *False* if not.

# %%
students['name'].hasnans
# Out:
# True

# %% [markdown]
# Trying `isnull()` and `notnull()` on a whole DataFrame.

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %% [markdown]
# ### `dropna()`
# Drops the rows with **NaN** values. Works on both Series and DataFrames.

# %%
students['name'].dropna()
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
# will remove all the rows with a missing value in any column
students.dropna()
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %% [markdown]
# The strategy in the above code cell might prove to be a rather primitive one, since it banishes the rows with missing value in *any* column. This shall be overcome by using the method in the following code cell.
#
# The below code cell will ensure to drop only the row which has **NaN** values in all the columns.

# %%
students.dropna(how='all')
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %% [markdown]
# Now suppose that we want to drop a row with **NaN** values only in one of the columns, then we will use the following method:

# %%
students.dropna(subset=['name'])
# Out:
#          name college branch  cgpa  package
# 0      nitish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 8      aditya     NaN    bio  7.40      NaN

# %% [markdown]
# We can also select multiple subsets.

# %%
students.dropna(subset=['name', 'college'])
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %% [markdown]
# ### `fillna()`
# Replaces the **NaN** values with some custom value.

# %%
students['name'].fillna('Unknown')
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3       Unknown
# 4    mrityunjay
# 5       Unknown
# 6       rishabh
# 7       Unknown
# 8        aditya
# 9       Unknown
# Name: name, dtype: object

# %%
students['package'].fillna(students['package'].mean())
# Out:
# 0    4.000000
# 1    5.000000
# 2    6.000000
# 3    6.428571
# 4    6.000000
# 5    7.000000
# 6    8.000000
# 7    9.000000
# 8    6.428571
# 9    6.428571
# Name: package, dtype: float64

# %%
students['name'].fillna(method='ffill')
# Out:
# /tmp/ipykernel_6919/538422019.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students['name'].fillna(method='ffill')
# 0        nitish
# 1         ankit
# 2        rupesh
# 3        rupesh
# 4    mrityunjay
# 5    mrityunjay
# 6       rishabh
# 7       rishabh
# 8        aditya
# 9        aditya
# Name: name, dtype: object

# %% [markdown]
# ### `drop_duplicates()`
# Drops all the duplicated rows in a DataFrame. The duplicate rows can be located with the help of `duplicated()`. The `keep` param in `drop_duplicates()` decides which occurence of the duplicate to remove and which to keep.

# %%
marks.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
marks.drop_duplicates(keep='last')
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14

# %% [markdown]
# #### Task: Find the last match played by Virat Kohli in Delhi.
# We will form a new column, listing all the players that played in Team1 as well as Team2, i.e. 22 players, 11 in each team.

# %%
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
#
#                    WinningTeam    WonBy Margin  method Player_of_Match  \
# 0               Gujarat Titans  Wickets    7.0     NaN       HH Pandya
# 1             Rajasthan Royals  Wickets    7.0     NaN      JC Buttler
# ...

# %%
playerCheckMask = ipl['all_players'].apply(lambda players: 'V Kohli' in players)
playerCheckMask
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 945    False
# 946     True
# 947    False
# 948    False
# 949     True
# Name: all_players, Length: 950, dtype: bool

# %%
cityCheckMask = ipl['City'] == 'Delhi'
cityCheckMask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947     True
# 948    False
# 949    False
# Name: City, Length: 950, dtype: bool

# %%
# strategy 1
ipl[playerCheckMask & cityCheckMask].drop_duplicates(subset=['City'], keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ...     WinningTeam WonBy Margin  method Player_of_Match  \
# 208          bat  ...  Delhi Capitals  Runs   16.0     NaN        S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
# [1 rows x 21 columns]

# %%
# strategy 2
ipl[playerCheckMask & cityCheckMask].sort_values(by='Season').iloc[[-1]]
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ...     WinningTeam WonBy Margin  method Player_of_Match  \
# 208          bat  ...  Delhi Capitals  Runs   16.0     NaN        S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
# [1 rows x 21 columns]

# %% [markdown]
# ### `drop()`
# Drops the rows and columns by **index** or **column names**. The `index` param receives either the index number or the index label for deletion of rows. Applicable on both Series and DataFrame

# %%
temp = pd.Series([10, 2, 3, 16, 45, 78, 10])
temp
# Out:
# 0    10
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# 6    10
# dtype: int64

# %%
temp.drop(index=[0, 6])
# Out:
# 1     2
# 2     3
# 3    16
# 4    45
# 5    78
# dtype: int64

# %%
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.drop(columns=['branch', 'cgpa'], inplace=True)

# %%
students
# Out:
#          name college  package
# 0      nitish     bit      4.0
# 1       ankit     iit      5.0
# 2      rupesh     vit      6.0
# 3         NaN     NaN      NaN
# 4  mrityunjay     NaN      6.0
# 5         NaN    vlsi      7.0
# 6     rishabh    ssit      8.0
# 7         NaN     NaN      9.0
# 8      aditya     NaN      NaN
# 9         NaN     git      NaN

# %%
students.drop(index=[0, 8])
# Out:
#          name college  package
# 1       ankit     iit      5.0
# 2      rupesh     vit      6.0
# 3         NaN     NaN      NaN
# 4  mrityunjay     NaN      6.0
# 5         NaN    vlsi      7.0
# 6     rishabh    ssit      8.0
# 7         NaN     NaN      9.0
# 9         NaN     git      NaN

# %% [markdown]
# ### `apply()`
# Applies a custom function, or mostly a lambda function to a Series or a DataFrame. Applicable to both Series and DataFrames. Some applications of `apply()` are provided below.

# %%
temp = pd.Series([10, 20, 30, 40, 50])

temp
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
def sigmoid(value):
    return 1/1+np.exp(value)

# %%
temp.apply(sigmoid)
# Out:
# 0    2.202747e+04
# 1    4.851652e+08
# 2    1.068647e+13
# 3    2.353853e+17
# 4    5.184706e+21
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
    pt_A = row['1st point']
    pt_B =  row['2nd point']

    return ((pt_A[0] - pt_B[0]) ** 2 + (pt_A[1] - pt_B[1]) ** 2) ** 0.5

# %%
points_df['distance'] = points_df.apply(euclidean, axis=1)

# %%
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
